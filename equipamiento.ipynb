# %% [markdown]
# # Equipamiento Urbano
# ## Ayuntamiento de Barcelona

# %%
import pandas as pd

# %% [markdown]
# ## Cultura.
# ### centros civicos

# %%
civic = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\cultura\\2021_centres_civics_entitats.csv")

# %%
civic.Notes_Dades.isna().sum()
# Out:
# 102

# %%
civic.drop(columns=["Any", "Ambit", "Notes_Dades", "Notes_Equipament", "TipusEquipament", "TipusGeneral", "Titularitat"], inplace=True)

# %% [markdown]
# Cambiar indicador a columna y valores en cada centro civico.

# %%
civic.TipusEquipament.value_counts()
# Out:
# Centres cívics    102
# Name: TipusEquipament, dtype: int64

# %%
civic
# Out:
#       Any                            Equipament          Indicador  Valor  \
# 0    2021              Centre Cívic Barceloneta  TotalUsosEntitats    130
# 1    2021              Centre Cívic Barceloneta    Metres_quadrats   1431
# 2    2021            Centre Cívic Baró de Viver  TotalUsosEntitats     39
# 3    2021            Centre Cívic Baró de Viver    Metres_quadrats   1535
# 4    2021                    Centre Cívic Besòs  TotalUsosEntitats      0
# ..    ...                                   ...                ...    ...
# 97   2021                Centre Cívic Zona Nord    Metres_quadrats   2418
# 98   2021              Centre Cultural Albareda  TotalUsosEntitats    203
# 99   2021              Centre Cultural Albareda    Metres_quadrats   1473
# 100  2021  Centre Cultural la Farinera del Clot  TotalUsosEntitats     84
# 101  2021  Centre Cultural la Farinera del Clot    Metres_quadrats   2634
#
#      Notes_Dades Notes_Equipament  Codi_Districte   Nom_Districte  Codi_Barri  \
# ...

# %% [markdown]
# ### Culture_leissure

# %% [markdown]
# es un general de toda la cultura de todos los otros df

# %%
culture = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\cultura\culture_leissure.csv")

# %%
esta todo lo de el data frame de abajo museums y bibliotecs

# %%
culture.secondary_filters_name.value_counts()
# Out:
# Àrees de jocs infantils        601
# Parcs i jardins                306
# Bars i pubs musicals           200
# Biblioteques                   186
# WiFi BCN                       157
# Teatres                        130
# Xampanyeries                   126
# Cocteleries                    126
# Casals d'avis                  114
# Sales d'estudi                  95
# Discoteques                     78
# Museus                          74
# Restaurants                     58
# Centres cívics                  53
# Biblioteques municipals         50
# Interiors d'illa                49
# Casals i espais per a joves     47
# Casals de barri                 40
# Casals infantils                29
# Cinemes                         28
# Auditoris                       26
# Museus municipals               21
# Bancs del Temps                 18
# Arxius municipals               16
# Karaokes                        10
# Tablaos flamencs                 8
# Altres esports                   8
# ...

# %%
culture
# Out:
#        register_id                         name  institution_id  \
# 0     ﻿75990035678  Bar musical Flann O'Brien's             NaN
# 1       ﻿136112242      Centre Cívic Pere Pruna             NaN
# 2       ﻿136112242      Centre Cívic Pere Pruna             NaN
# 3     ﻿92086034526       Centre Cívic Drassanes             NaN
# 4     ﻿92086034526       Centre Cívic Drassanes             NaN
# ...            ...                          ...             ...
# 2682  ﻿92086011921        Parc de la Ciutadella             NaN
# 2683  ﻿92086011921        Parc de la Ciutadella             NaN
# 2684  ﻿92086009953            CRAI - Biblioteca    9.208601e+10
# 2685  ﻿92086009953            CRAI - Biblioteca    9.208601e+10
# 2686  ﻿99400165038            Teatre - Auditori    9.208600e+10
#
#                            institution_name                    created  \
# 0                                       NaN  1996-09-17T00:00:00+02:00
# ...

# %% [markdown]
# ### restaurants

# %%
mus = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\cultura\\restaurants.csv")

# %%
mus.secondary_filters_name.value_counts()
# Out:
# Restaurants             2494
# Cocteleries               35
# Xampanyeries              35
# Bars i pubs musicals      15
# Tablaos flamencs           5
# Discoteques                4
# Karaokes                   2
# Teatres                    1
# Name: secondary_filters_name, dtype: int64

# %%
mus
# Out:
#        register_id                                         name  \
# 0       ﻿280131454  Restaurant Els Pollos de Llull *Ramon Turró
# 1     ﻿99400280889                         Restaurant La Royale
# 2     ﻿75990055450                       Restaurant Ca l'Isidre
# 3     ﻿75990023271                        Bar Restaurant Baztan
# 4     ﻿75990025015                           Restaurant Maccabi
# ...            ...                                          ...
# 2586  ﻿99400611908                                  Bar Neutral
# 2587  ﻿99400603462                   Restaurant Khalijia Shisha
# 2588  ﻿99400707533                   Hamburgueseria Rock & Boom
# 2589  ﻿99400707536                      Restaurant Bo de Bernat
# 2590  ﻿99400707540                       Bar Restaurant Chamako
#
#       institution_id institution_name                           created  \
# 0                NaN              NaN         2000-10-06T00:00:00+02:00
# ...

# %% [markdown]
# ### Museum libraries. NOT

# %%
mus = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\cultura\museum_libraries.csv")

# %%
mus.drop(columnns=["register_id", "institution_id", "institution_name", "created", "modified", "addresses_roadtype_id", "addresses_roadtype_name",
                   "addresses_road_id", "values_description", "secondary_filters_id", "secondary_filters_fullpath"])

# %%
mus.secondary_filters_name.value_counts()
# Out:
# Biblioteques                 186
# Sales d'estudi                95
# Museus                        74
# Biblioteques municipals       50
# Museus municipals             21
# Arxius municipals             16
# WiFi BCN                      13
# Universitats                   2
# Parcs i jardins                1
# Altres esports                 1
# Natació                        1
# Instal·lacions esportives      1
# Name: secondary_filters_name, dtype: int64

# %%
mus
# Out:
#       register_id                                         name  \
# 0    ﻿92168151705                         Biblioteca Joan Miró
# 1    ﻿92168151705                         Biblioteca Joan Miró
# 2    ﻿92168151705                         Biblioteca Joan Miró
# 3    ﻿92163150849  Museu Futbol Club Barcelona President Núñez
# 4    ﻿99400218118               Museu del Disseny de Barcelona
# ..            ...                                          ...
# 456  ﻿99400299968  Biblioteca Camp de l'Arpa - Caterina Albert
# 457  ﻿99400448268              CRAI - Biblioteca de Fons Antic
# 458  ﻿99400622824  Sala d'Estudi Montserrat Abelló - Les Corts
# 459  ﻿99400613287                        Biblioteca Marta Mata
# 460  ﻿99400678872            EcoMuseu Urbà Gitano de Barcelona
#
#      institution_id              institution_name  \
# 0               NaN                           NaN
# 1               NaN                           NaN
# 2               NaN                           NaN
# ...

# %% [markdown]
# ### music and drinks. NOT

# %%
drinks = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\cultura\music_drinks.csv")

# %%
drinks.secondary_filters_name.value_counts()
# Out:
# Bars i pubs musicals         200
# Cocteleries                  126
# Xampanyeries                 126
# Discoteques                   78
# Restaurants                   57
# Karaokes                      10
# Tablaos flamencs               8
# Salons de ball                 6
# Sales de festes                4
# Teatres                        2
# Altres esports                 1
# Instal·lacions esportives      1
# Name: secondary_filters_name, dtype: int64

# %%
drinks
# Out:
#       register_id                              name  institution_id  \
# 0    ﻿99400158645               Karaoke Touch Music             NaN
# 1    ﻿99400593707  Cocteleria P41 Bar & Coctelarium    7.599027e+10
# 2    ﻿99400593707  Cocteleria P41 Bar & Coctelarium    7.599027e+10
# 3    ﻿99400632799              Golden Shisha Lounge             NaN
# 4    ﻿92086038702                      Bar Marsella             NaN
# ..            ...                               ...             ...
# 614  ﻿99400706558                   Cocteleria Nola             NaN
# 615  ﻿99400706558                   Cocteleria Nola             NaN
# 616  ﻿99400707531              Bar Soda bus & Verne             NaN
# 617  ﻿99400707531              Bar Soda bus & Verne             NaN
# 618  ﻿99400707531              Bar Soda bus & Verne             NaN
#
#                      institution_name                           created  \
# 0                                 NaN         2006-05-10T13:15:59+02:00
# ...

# %% [markdown]
# ## educacion.
# ### escuelas

# %%
schools = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\equipamiento\education.csv")

# %%
schools.drop(columns=["register_id"])

# %%
schools
# Out:
#        register_id                                               name  \
# 0       ﻿130115232                                      Fundació Èxit
# 1     ﻿92168166344                          Centre Educatiu Valldaura
# 2     ﻿92168166344                          Centre Educatiu Valldaura
# 3     ﻿92168166344                          Centre Educatiu Valldaura
# 4     ﻿75990423787  Institut de Formació i Promoció Laboral Clau d...
# ...            ...                                                ...
# 2674  ﻿99400707626               Centre de Ioga Blanc Yoga *Les Corts
# 2675  ﻿99400604497                Centre de Ioga Blanc Yoga *Eixample
# 2676  ﻿99400604508                          Centre de Ioga Més Millor
# 2677  ﻿99400604498                       Centre de Ioga Yoga Ecuanime
# 2678  ﻿92168165429                            Llar d'Infants Kasperle
#
#       institution_id institution_name                           created  \
# ...

# %% [markdown]
# ### hospitals

# %%
hospitals = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\equipamiento\hospitals.csv")

# %%
hospitals
# Out:
#       register_id                                               name  \
# 0    ﻿92086002898  Hospital El Pilar - Institut Cardiovascular Sa...
# 1    ﻿94040143759              Centre d'Atenció Primària Vallvidrera
# 2    ﻿99400012795                     Centre d'Atenció Primària Turó
# 3    ﻿94286182144                  Centre d'Atenció Primària El Clot
# 4    ﻿99400279672                                Clínica Sant Antoni
# ..            ...                                                ...
# 137  ﻿99400284987        Centre d'Urgències d'Atenció Primària Horta
# 138  ﻿99400344819                 Centre d'Atenció Primària Casernes
# 139  ﻿99400699333                                  Clínica Oftalvist
# 140  ﻿99400706702                  Centre Mèdic Vilasalut *Barcelona
# 141  ﻿99400706694                                   Clínica Cipsalut
#
#      institution_id                                   institution_name  \
# ...

# %% [markdown]
# ### play-ground

# %%
play = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\equipamiento\school_playground.csv")

# %%
play
# Out:
#      register_id                                               name  \
# 0   ﻿99400472916  Patis escolars oberts al barri - Escola Mossèn...
# 1   ﻿99400630189  Patis escolars oberts al barri - Institut Mené...
# 2   ﻿99400691081  Patis escolars oberts al barri - Escola Bresso...
# 3   ﻿99400705006  Patis escolars oberts al barri- Institut Vapor...
# 4   ﻿99400704985  Patis escolars oberts al barri - Escola Bresso...
# ..           ...                                                ...
# 80  ﻿99400705008   Patis escolars oberts al barri- Escola El Sagrer
# 81  ﻿99400704992  Patis escolars oberts al barri - Escola Bresso...
# 82  ﻿99400704994  Patis escolars oberts al barri - Escola Bresso...
# 83  ﻿99400704997  Patis escolars oberts al barri - Escola Bresso...
# 84  ﻿99400705818   Patis escolars oberts al barri - Escola Montseny
#
#     institution_id  institution_name                           created  \
# 0              NaN               NaN         2016-12-22T08:31:59+01:00
# ...

# %% [markdown]
# ## SPORT
# ### excersice

# %%
exc = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\sports\excersice.csv")

# %%
exc
# Out:
#      register_id                                               name  \
# 0   ﻿99400297249                                     Àrea Esportiva
# 1   ﻿99400297250  Àrea Esportiva *Pardo - Can Ros - Concepció Ar...
# 2   ﻿99400297205                                     Àrea Esportiva
# 3   ﻿99400575466            Espai Gimnàstic per a Gent Gran *Pujalt
# 4   ﻿99400575501  Espai Gimnàstic per a Gent Gran *Jocs Esportiu...
# 5   ﻿99400575506                    Espai Gimnàstic per a Gent Gran
# 6   ﻿99400575508      Espai Gimnàstic per a Gent Gran  *Plaça Navas
# 7   ﻿99400575430                    Espai Gimnàstic per a Gent Gran
# 8   ﻿99400575450                    Espai Gimnàstic per a Gent Gran
# 9   ﻿99400575454  Espai Gimnàstic per a Gent Gran  *Parc Sanitar...
# 10  ﻿99400575456                    Espai Gimnàstic per a Gent Gran
# 11  ﻿99400575462                    Espai Gimnàstic per a Gent Gran
# 12  ﻿99400575421    Espai Gimnàstic per a Gent Gran  *Arc de Teatre
# ...

# %% [markdown]
# ### pools.

# %%
pool = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\sports\pools.csv")

# %%
pool.columns
# Out:
# Index(['register_id', 'name', 'institution_id', 'institution_name', 'created',
#        'modified', 'addresses_roadtype_id', 'addresses_roadtype_name',
#        'addresses_road_id', 'addresses_road_name',
#        'addresses_start_street_number', 'addresses_end_street_number',
#        'addresses_neighborhood_id', 'addresses_neighborhood_name',
#        'addresses_district_id', 'addresses_district_name',
#        'addresses_zip_code', 'addresses_town', 'addresses_main_address',
#        'addresses_type', 'values_id', 'values_attribute_id', 'values_category',
#        'values_attribute_name', 'values_value', 'values_outstanding',
#        'values_description', 'geo_epgs_25831_x', 'geo_epgs_25831_y',
#        'geo_epgs_4326_x', 'geo_epgs_4326_y'],
#       dtype='object')

# %% [markdown]
# ### walk circuit

# %%
walk = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\sports\walk_run_circuits.csv")

# %%
walk
# Out:
#      register_id                                             name  \
# 0   ﻿99400575099  Circuit Esportiu Castell de Montjuïc *circuit 1
# 1   ﻿99400575152               Circuit Esportiu Aragó - Guipúscoa
# 2   ﻿92086011919                                 Circuit Esportiu
# 3   ﻿99400099215           Circuit Esportiu Mirador de les Aigües
# 4   ﻿99400099221                Circuit  Esportiu Passeig Marítim
# 5    ﻿1302123624          Circuit de Fitness del Parc del Litoral
# 6   ﻿99400575142           Circuit Esportiu Diagonal - Sant Martí
# 7   ﻿99400109378                                 Circuit Esportiu
# 8   ﻿99400099219                    Circuit  Esportiu Rambla Prim
# 9   ﻿93067092632            Circuit Esportiu Diagonal - Cervantes
# 10  ﻿99400575090                                 Circuit Esportiu
# 11  ﻿99400575122  Circuit Esportiu Castell de Montjuïc *circuit 2
# 12  ﻿99400575130                       Circuit Esportiu Can Dragó
#
# ...
