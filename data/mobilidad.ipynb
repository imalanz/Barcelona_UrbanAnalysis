# %% [markdown]
# # Mobilidad.

# %% [markdown]
# ### Bicing.

# %%
import pandas as pd
import json
from pandas import json_normalize

import importlib
import sys 
sys.path.append("..\src")
import mobilidad as mo
importlib.reload(mo)
# Out:
# <module 'mobilidad' from 'd:\\ironhack\\proyectos\\Barcelona_UrbanAnalysis\\data\\..\\src\\mobilidad.py'>

# %%
bici = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\\bicing\\2019BICING_ESTACIONS.csv")

# %%
x = mo.bici_(bici)
# Out:
# d:\ironhack\proyectos\Barcelona_UrbanAnalysis\data\..\src\mobilidad.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)
# d:\ironhack\proyectos\Barcelona_UrbanAnalysis\data\..\src\mobilidad.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
x.sample()
# Out:
#                            address bikes category   division  latitud  \
# 302466  (PK) PL. GAL·LA PLACÍDIA 2     4   bicing  mobilidad  41.3989
#
#         longitud
# 302466  2.153668

# %%
x.to_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv_from_python\mobilidad\\bicing.csv", index=False)

# %% [markdown]
# ### Bicipuertos.

# %%
with open("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\\bicing\\bicipuertos.json") as f:
    puertos = json.load(f)

# %%
puertos = mo.bicipuertos (puertos)

# %%
puertos.sample()
# Out:
#                           address district_id      district barri_id  \
# 3908  TORRAS I BAGES, PG., DE 19           09   Sant Andreu       60
#
#              barri     category   division    latitud  longitud
# 3908   Sant Andreu  puerto_bici  mobilidad  41.377359  2.147228

# %%
puertos.to_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv_from_python\mobilidad\\bicipuertos.csv", index=False)

# %% [markdown]
# ### Buses.

# %%
bus = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\\transporte_publico\ESTACIONS_BUS.csv")

# %%
bus = mo.buses (bus)

# %%
bus.sample()
# Out:
#               name  district_id   district  barri_id      barri  \
# 2329  NITBUS -N0--            4  Les Corts        19  les Corts
#
#                 category   division    latitud  longitud
# 2329  Autobusos nocturns  mobilidad  41.386169  2.135895

# %%
bus.to_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv_from_python\mobilidad\\bus_stops.csv", index=False)

# %% [markdown]
# ### Transportes.

# %%
tran = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\\transporte_publico\TRANSPORTS.csv")

# %%
tran = mo.clean_transportes(tran)
# Out:
# d:\ironhack\proyectos\Barcelona_UrbanAnalysis\data\..\src\mobilidad.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
tran.sample()
# Out:
#                          name district_id    district barri_id         barri  \
# 459  Roquetes (Jaume Pinent)-           8  Nou Barris       50  les Roquetes
#
#                        category   division    latitud  longitud
# 459  Metro i línies urbanes FGC  mobilidad  41.446877  2.174904

# %%
tran.to_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv_from_python\mobilidad\\metro_train.csv", index=False)

# %%
outer_merge = pd.merge(tran, bici, how="outer")

# %%
x = pd.merge(outer_merge, puertos, how="outer")

# %%
y = pd.concat(x, bus)
# Out:
# C:\Users\ima_n\AppData\Local\Temp\ipykernel_2028\3488437701.py:1: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   y = pd.concat(x, bus)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 y = pd.concat(x, bus)
#
# File c:\Users\ima_n\miniconda2\envs\final_proy\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\ima_n\miniconda2\envs\final_proy\lib\site-packages\pandas\core\reshape\concat.py:368, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     146 @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#     147 def concat(
#     148     objs: Iterable[NDFrame] | Mapping[HashableT, NDFrame],
#    (...)
#     157     copy: bool = True,
#     158 ) -> DataFrame | Series:
#     159     """
#     160     Concatenate pandas objects along a particular axis.
#     161
#    (...)
#     366     1   3   4
#     367     """
# --> 368     op = _Concatenator(
#     369         objs,
#     370         axis=axis,
#     371         ignore_index=ignore_index,
#     372         join=join,
#     373         keys=keys,
#     374         levels=levels,
#     375         names=names,
#     376         verify_integrity=verify_integrity,
#     377         copy=copy,
#     378         sort=sort,
#     379     )
#     381     return op.get_result()
#
# File c:\Users\ima_n\miniconda2\envs\final_proy\lib\site-packages\pandas\core\reshape\concat.py:403, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     389 def __init__(
#     390     self,
#     391     objs: Iterable[NDFrame] | Mapping[HashableT, NDFrame],
#    (...)
#     400     sort=False,
#     401 ) -> None:
#     402     if isinstance(objs, (ABCSeries, ABCDataFrame, str)):
# --> 403         raise TypeError(
#     404             "first argument must be an iterable of pandas "
#     405             f'objects, you passed an object of type "{type(objs).__name__}"'
#     406         )
#     408     if join == "outer":
#     409         self.intersect = False
#
# TypeError: first argument must be an iterable of pandas objects, you passed an object of type "DataFrame"

# %%
outer_merge
# Out:
#                                        name district_id             district  \
# 0                     Tren AEROPORT - CLOT-          10           Sant Martí
# 1                           FGC - BONANOVA-           5  Sarrià-Sant Gervasi
# 2                          FGC - EL PUTXET-           5  Sarrià-Sant Gervasi
# 3                 Clot (Aragó / Meridiana)-          10           Sant Martí
# 4        Fabra i Puig (Avinguda Meridiana)-           9          Sant Andreu
# ...                                     ...         ...                  ...
# 1545564                                 NaN         NaN                  NaN
# 1545565                                 NaN         NaN                  NaN
# 1545566                                 NaN         NaN                  NaN
# 1545567                                 NaN         NaN                  NaN
# 1545568                                 NaN         NaN                  NaN
#
#         barri_id                   barri                        category  \
# 0             65                 el Clot               Tren a l'aeroport
# 1             26  Sant Gervasi - Galvany  Ferrocarrils Generalitat (FGC)
# 2             27    el Putxet i el Farró  Ferrocarrils Generalitat (FGC)
# 3             65                 el Clot      Metro i línies urbanes FGC
# 4             60             Sant Andreu      Metro i línies urbanes FGC
# ...          ...                     ...                             ...
# 1545564      NaN                     NaN                          bicing
# 1545565      NaN                     NaN                          bicing
# 1545566      NaN                     NaN                          bicing
# 1545567      NaN                     NaN                          bicing
# 1545568      NaN                     NaN                          bicing
#
#           division    latitud  longitud bikes      address
# 0        mobilidad  41.410259  2.189397   NaN          NaN
# 1        mobilidad  41.397791  2.135427   NaN          NaN
# 2        mobilidad  41.405731  2.139248   NaN          NaN
# 3        mobilidad  41.409376  2.187234   NaN          NaN
# 4        mobilidad  41.430013  2.183681   NaN          NaN
# ...            ...        ...       ...   ...          ...
# 1545564  mobilidad  41.410538  2.158100     0  Cardener 82
# 1545565  mobilidad  41.410538  2.158100     0  Cardener 82
# 1545566  mobilidad  41.410538  2.158100     0  Cardener 82
# 1545567  mobilidad  41.410538  2.158100     0  Cardener 82
# 1545568  mobilidad  41.410538  2.158100     0  Cardener 82
#
# [1545569 rows x 11 columns]
