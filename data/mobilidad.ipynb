# %% [markdown]
# # Mobilidad.

# %% [markdown]
# ### Bicing.

# %%
import pandas as pd
import json
from pandas import json_normalize

import importlib
import sys 
sys.path.append("..\src")
import mobilidad as mo
importlib.reload(mo)
# Out:
# <module 'mobilidad' from 'd:\\ironhack\\proyectos\\Barcelona_UrbanAnalysis\\data\\..\\src\\mobilidad.py'>

# %%
bici = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\\bicing\\2019BICING_ESTACIONS.csv")

# %%
bici
# Out:
#           id  type   latitude  longitude                streetName  \
# 0          1  BIKE  41.397952   2.180042  Gran Via Corts Catalanes
# 1          2  BIKE  41.395530   2.177060   Roger de Flor/ Gran Vía
# 2          3  BIKE  41.394055   2.181299                    Nàpols
# 3          4  BIKE  41.393480   2.181555                     Ribes
# 4          5  BIKE  41.391075   2.180223         Pg Lluís Companys
# ...      ...   ...        ...        ...                       ...
# 1545076  277  BIKE  41.408284   2.169050      Travessera de Gràcia
# 1545077  278  BIKE  41.409815   2.171621      Travessera de Gràcia
# 1545078  279  BIKE  41.415951   2.174564             Mas Casanovas
# 1545079  280  BIKE  41.413986   2.177842     Sant Antoni Mª Claret
# 1545080  281  BIKE  41.418088   2.176313               Escornalbou
#
#         streetNumber  altitude  slots  bikes      nearbyStations status  \
# 0                760        21   10.0   16.0   24, 369, 387, 426    OPN
# ...

# %%
x = mo.bici_(bici)
# Out:
# d:\ironhack\proyectos\Barcelona_UrbanAnalysis\data\..\src\mobilidad.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)
# d:\ironhack\proyectos\Barcelona_UrbanAnalysis\data\..\src\mobilidad.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
x["sub_category"] = "bicing"
# Out:
# C:\Users\ima_n\AppData\Local\Temp\ipykernel_2028\3890464631.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x["sub_category"] = "bicing"

# %%
x.sample()
# Out:
#             address bikes category   division    latitud  longitud  \
# 55202  Sardenya 362    10   bicing  mobilidad  41.405422   2.17064
#
#       sub_category
# 55202       bicing

# %%
x.to_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv_from_python\mobilidad\\bicing.csv", index=False)

# %% [markdown]
# ### Bicipuertos.

# %%
with open("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\\bicing\\bicipuertos.json") as f:
    puertos = json.load(f)

# %%
puertos = mo.bicipuertos (puertos)

# %%
puertos
# Out:
#                          address district_id   district barri_id  \
# 0          MARINA, C., DE LA 309          02   Eixample       06
# 1          MARINA, C., DE LA 293          02   Eixample       06
# 2          MARINA, C., DE LA 311          02   Eixample       06
# 3          MARINA, C., DE LA 325          02   Eixample       06
# 4              LLANÇA, C., DE 23          02   Eixample       09
# ...                          ...         ...        ...      ...
# 3922  ENRIC GRANADOS, C., D' 95           02   Eixample       08
# 3923        PROVENÇA, C., DE 80           02   Eixample       09
# 3924     VILLARROEL, C., DE 136           02   Eixample       08
# 3925        MALLORCA, C., DE 41           02   Eixample       09
# 3926       TARRAGONA, C., DE 74           02   Eixample       09
#
#                                  barri     category   division    latitud  \
# 0                   la Sagrada Familia  puerto_bici  mobilidad  41.377359
# ...

# %%
puertos["sub_category"] = "bici_puerto"

# %%
puertos.sample()
# Out:
#                 address district_id   district barri_id           barri  \
# 1750  RIBES, C., DE 12           02   Eixample       05   el Fort Pienc
#
#          category   division    latitud  longitud sub_category
# 1750  puerto_bici  mobilidad  41.377359  2.147228  bici_puerto

# %%
puertos.to_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv_from_python\mobilidad\\bicipuertos.csv", index=False)

# %% [markdown]
# ### Buses.

# %%
bus = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\\transporte_publico\ESTACIONS_BUS.csv")

# %%
bus = mo.buses (bus)

# %%
bus["sub_category"] = "bus"

# %%
bus.sample()
# Out:
#                name  district_id  district  barri_id  \
# 1988  BUS -H12-52--            2  Eixample         8
#
#                                 barri          category   division    latitud  \
# 1988  l'Antiga Esquerra de l'Eixample  Autobusos diürns  mobilidad  41.385938
#
#       longitud sub_category
# 1988  2.163336          bus

# %%
bus.to_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv_from_python\mobilidad\\bus_stops.csv", index=False)

# %% [markdown]
# ### Transportes.

# %%
tran = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\\transporte_publico\TRANSPORTS.csv")

# %%
tran = mo.clean_transportes(tran)
# Out:
# d:\ironhack\proyectos\Barcelona_UrbanAnalysis\data\..\src\mobilidad.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
tran["sub_category"] = "metro"

# %%
tran.sample()
# Out:
#                      name district_id  district barri_id  \
# 254  METRO (L2) - Tetuan-           2  Eixample        7
#
#                       barri                    category   division    latitud  \
# 254  la Dreta de l'Eixample  Metro i línies urbanes FGC  mobilidad  41.394915
#
#      longitud sub_category
# 254  2.175585        metro

# %%
tran.to_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv_from_python\mobilidad\\metro_train.csv", index=False)
