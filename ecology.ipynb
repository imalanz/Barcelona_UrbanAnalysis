# %% [markdown]
# # Environment
# ## Ayuntamiento de Barcelona

# %%
import plotly.express as px
import geopandas as gpd
import shapely.geometry
import numpy as np
import wget
import fiona
import folium

# %%
import pandas as pd
import plotly.graph_objects as go

# %%
x = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\calidad de aire\\2022_qualitat_aire_estacions.csv")

# %%
x
# Out:
#      CODI_PROVINCIA  PROVINCIA  CODI_MUNICIPI   MUNICIPI  ESTACIO  \
# 0                 8  Barcelona             19  Barcelona       43
# 1                 8  Barcelona             19  Barcelona       43
# 2                 8  Barcelona             19  Barcelona       43
# 3                 8  Barcelona             19  Barcelona       43
# 4                 8  Barcelona             19  Barcelona       54
# ..              ...        ...            ...        ...      ...
# 255               8  Barcelona             19  Barcelona       57
# 256               8  Barcelona             19  Barcelona       57
# 257               8  Barcelona             19  Barcelona       57
# 258               8  Barcelona             19  Barcelona       57
# 259               8  Barcelona             19  Barcelona       57
#
#      CODI_CONTAMINANT   ANY  MES  DIA    H01  ...    H20  V20    H21  V21  \
# 0                 999  2023    3    6  31.10  ...  20.40    V  22.30    V
# 1                 999  2023    3    7  18.50  ...  19.70    V  21.90    V
# 2                 999  2023    3    8  21.40  ...  20.00    V  21.20    V
# 3                 999  2023    3    9  20.70  ...    NaN    N    NaN    N
# 4                 999  2023    3    6  22.70  ...  14.90    V  18.70    V
# ..                ...   ...  ...  ...    ...  ...    ...  ...    ...  ...
# 255               109  2023    3    9   3.80  ...    NaN    N    NaN    N
# 256               101  2023    3    6   2.63  ...   2.65    V   2.54    V
# 257               101  2023    3    7   2.61  ...   2.79    V   2.78    V
# 258               101  2023    3    8   2.60  ...   2.95    V   3.18    V
# 259               101  2023    3    9   4.34  ...    NaN    N    NaN    N
#
#        H22  V22    H23  V23    H24  V24
# 0    23.30    V  23.10    V  22.70    V
# 1    23.00    V  23.60    V  22.70    V
# 2    18.20    V  20.20    V  20.20    V
# 3      NaN    N    NaN    N    NaN    N
# 4    19.70    V  24.20    V  25.10    V
# ..     ...  ...    ...  ...    ...  ...
# 255    NaN    N    NaN    N    NaN    N
# 256   2.51    V   2.73    V   2.62    V
# 257   2.39    V   2.63    V   2.53    V
# 258   2.93    V   3.00    V   3.86    V
# 259    NaN    N    NaN    N    NaN    N
#
# [260 rows x 57 columns]

# %%
# para sacar el contaminante en la tabla de arriba la general por barrio.
x = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\calidad de aire\contaminants.csv")
x
# Out:
#     Codi_Contaminant                Desc_Contaminant Unitats
# 0                  1                             SO2   µg/m³
# 1                  7                              NO   µg/m³
# 2                  8                             NO2   µg/m³
# 3                  9                           PM2.5   µg/m³
# 4                 12                             NOx   µg/m³
# 5                 14                              O3   µg/m³
# 6                  6                              CO   mg/m³
# 7                 10                            PM10   µg/m³
# 8                 22                    Black Carbon   µg/m³
# 9                999           Biomassa Black Carbon       %
# 10               998  Flow C (Mesura interna equip)
# 11               997   Flow 1 (Mesura interna equip)     NaN
# 12               996   Flow 2 (Mesura interna equip)     NaN

# %%
x.MES.value_counts()
# Out:
# 3    260
# Name: MES, dtype: int64

# %% [markdown]
# sacar el mean por dia, evaluar el tipo de contaminante por el codigo= buscarlo en el el df de los contaminantes
# conectar el data frame con el de arriba el completo para aberiguar la calidad por barrio con el codigo de la estacio.
# if estacio = entonces...

# %%
x = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\calidad de aire\Qualitat_Aire_Detall.csv")
x.sample(5)
# Out:
#      CODI_PROVINCIA  PROVINCIA  CODI_MUNICIPI   MUNICIPI  ESTACIO  \
# 163               8  Barcelona             19  Barcelona       44
# 36                8  Barcelona             19  Barcelona       54
# 205               8  Barcelona             19  Barcelona       43
# 32                8  Barcelona             19  Barcelona       43
# 13                8  Barcelona             19  Barcelona       54
#
#      CODI_CONTAMINANT   ANY  MES  DIA     H01  ...     H20  V20     H21  V21  \
# 163                14  2023    3    9    51.0  ...     NaN    N     NaN    N
# 36                997  2023    3    6  3822.2  ...  3855.0    V  3855.0    V
# 205               901  2023    3    7     0.0  ...     0.0    V     0.0    V
# 32                997  2023    3    6  3824.0  ...  3849.0    V  3849.0    V
# 13                 22  2023    3    7  1086.0  ...   558.0    V   476.0    V
#
#         H22  V22     H23  V23     H24  V24
# 163     NaN    N     NaN    N     NaN    N
# 36   3855.0    V  3854.6    V  3845.6    V
# 205     0.0    V     0.0    V     0.0    V
# 32   3848.3    V  3840.2    V  3865.2    V
# 13    580.0    V  1561.0    V  1384.0    V
#
# [5 rows x 57 columns]

# %%
x.ESTACIO.value_counts()
# Out:
# 57    64
# 43    52
# 54    52
# 44    28
# 58    20
# 50    16
# 4     16
# 42    12
# Name: ESTACIO, dtype: int64

# %%
x = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\calidad de aire\\2022_qualitat_aire_estacions.csv")

# %%
x
# Out:
#     Estacio                     nom_cabina codi_dtes  zqa  codi_eoi  Longitud  \
# 0        50         Barcelona - Ciutadella        IL    1   8019050    2.1874
# 1        50         Barcelona - Ciutadella        IL    1   8019050    2.1874
# 2        50         Barcelona - Ciutadella        IL    1   8019050    2.1874
# 3        50         Barcelona - Ciutadella        IL    1   8019050    2.1874
# 4        43           Barcelona - Eixample        IH    1   8019043    2.1538
# 5        43           Barcelona - Eixample        IH    1   8019043    2.1538
# 6        43           Barcelona - Eixample        IH    1   8019043    2.1538
# 7        43           Barcelona - Eixample        IH    1   8019043    2.1538
# 8        43           Barcelona - Eixample        IH    1   8019043    2.1538
# 9        43           Barcelona - Eixample        IH    1   8019043    2.1538
# 10       43           Barcelona - Eixample        IH    1   8019043    2.1538
# 11       44             Barcelona - Gràcia        IJ    1   8019044    2.1534
# 12       44             Barcelona - Gràcia        IJ    1   8019044    2.1534
# 13       44             Barcelona - Gràcia        IJ    1   8019044    2.1534
# 14       44             Barcelona - Gràcia        IJ    1   8019044    2.1534
# 15       44             Barcelona - Gràcia        IJ    1   8019044    2.1534
# 16       44             Barcelona - Gràcia        IJ    1   8019044    2.1534
# 17       44             Barcelona - Gràcia        IJ    1   8019044    2.1534
# 18       57        Barcelona - Palau Reial        IZ    1   8019057    2.1151
# 19       57        Barcelona - Palau Reial        IZ    1   8019057    2.1151
# 20       57        Barcelona - Palau Reial        IZ    1   8019057    2.1151
# 21       57        Barcelona - Palau Reial        IZ    1   8019057    2.1151
# 22       57        Barcelona - Palau Reial        IZ    1   8019057    2.1151
# 23       57        Barcelona - Palau Reial        IZ    1   8019057    2.1151
# 24       57        Barcelona - Palau Reial        IZ    1   8019057    2.1151
# 25        4           Barcelona - Poblenou        I2    1   8019004    2.2045
# 26        4           Barcelona - Poblenou        I2    1   8019004    2.2045
# 27        4           Barcelona - Poblenou        I2    1   8019004    2.2045
# 28        4           Barcelona - Poblenou        I2    1   8019004    2.2045
# 29       42              Barcelona - Sants        ID    1   8019042    2.1331
# 30       42              Barcelona - Sants        ID    1   8019042    2.1331
# 31       42              Barcelona - Sants        ID    1   8019042    2.1331
# 32       54        Barcelona - Vall Hebron        IN    1   8019054    2.1480
# 33       54        Barcelona - Vall Hebron        IN    1   8019054    2.1480
# 34       54        Barcelona - Vall Hebron        IN    1   8019054    2.1480
# 35       54        Barcelona - Vall Hebron        IN    1   8019054    2.1480
# 36       54        Barcelona - Vall Hebron        IN    1   8019054    2.1480
# 37       54        Barcelona - Vall Hebron        IN    1   8019054    2.1480
# 38       54        Barcelona - Vall Hebron        IN    1   8019054    2.1480
# 39       58  Barcelona - Observatori Fabra        IZ    1   8019058    2.1239
# 40       58  Barcelona - Observatori Fabra        IZ    1   8019058    2.1239
# 41       58  Barcelona - Observatori Fabra        IZ    1   8019058    2.1239
# 42       58  Barcelona - Observatori Fabra        IZ    1   8019058    2.1239
# 43       58  Barcelona - Observatori Fabra        IZ    1   8019058    2.1239
#
#      Latitud                                           ubicacio  \
# 0   41.38640                              Parc de la Ciutadella
# 1   41.38640                              Parc de la Ciutadella
# 2   41.38640                              Parc de la Ciutadella
# 3   41.38640                              Parc de la Ciutadella
# 4   41.38530                         Av. Roma - c/ Comte Urgell
# 5   41.38530                         Av. Roma - c/ Comte Urgell
# 6   41.38530                         Av. Roma - c/ Comte Urgell
# 7   41.38530                         Av. Roma - c/ Comte Urgell
# 8   41.38530                         Av. Roma - c/ Comte Urgell
# 9   41.38530                         Av. Roma - c/ Comte Urgell
# 10  41.38530                         Av. Roma - c/ Comte Urgell
# 11  41.39870  Plaça Gal·la Placídia (Via Augusta - Travesser...
# 12  41.39870  Plaça Gal·la Placídia (Via Augusta - Travesser...
# 13  41.39870  Plaça Gal·la Placídia (Via Augusta - Travesser...
# 14  41.39870  Plaça Gal·la Placídia (Via Augusta - Travesser...
# 15  41.39870  Plaça Gal·la Placídia (Via Augusta - Travesser...
# 16  41.39870  Plaça Gal·la Placídia (Via Augusta - Travesser...
# 17  41.39870  Plaça Gal·la Placídia (Via Augusta - Travesser...
# 18  41.38750        c/ John Maynard Keynes - c/ de Jordi Girona
# 19  41.38750        c/ John Maynard Keynes - c/ de Jordi Girona
# 20  41.38750        c/ John Maynard Keynes - c/ de Jordi Girona
# 21  41.38750        c/ John Maynard Keynes - c/ de Jordi Girona
# 22  41.38750        c/ John Maynard Keynes - c/ de Jordi Girona
# 23  41.38750        c/ John Maynard Keynes - c/ de Jordi Girona
# 24  41.38750        c/ John Maynard Keynes - c/ de Jordi Girona
# 25  41.40390        Plaça Josep Trueta (Pujades - Lope de Vega)
# 26  41.40390        Plaça Josep Trueta (Pujades - Lope de Vega)
# 27  41.40390        Plaça Josep Trueta (Pujades - Lope de Vega)
# 28  41.40390        Plaça Josep Trueta (Pujades - Lope de Vega)
# 29  41.37880  Jardins de Can Mantega (Joan Güell - Violant d...
# 30  41.37880  Jardins de Can Mantega (Joan Güell - Violant d...
# 31  41.37880  Jardins de Can Mantega (Joan Güell - Violant d...
# 32  41.42610  Parc de la Vall d’Hebron. c/ Martí Codolar - c...
# 33  41.42610  Parc de la Vall d’Hebron. c/ Martí Codolar - c...
# 34  41.42610  Parc de la Vall d’Hebron. c/ Martí Codolar - c...
# 35  41.42610  Parc de la Vall d’Hebron. c/ Martí Codolar - c...
# 36  41.42610  Parc de la Vall d’Hebron. c/ Martí Codolar - c...
# 37  41.42610  Parc de la Vall d’Hebron. c/ Martí Codolar - c...
# 38  41.42610  Parc de la Vall d’Hebron. c/ Martí Codolar - c...
# 39  41.41843                          Camí de l'Observatori-s/n
# 40  41.41843                          Camí de l'Observatori-s/n
# 41  41.41843                          Camí de l'Observatori-s/n
# 42  41.41843                          Camí de l'Observatori-s/n
# 43  41.41843                          Camí de l'Observatori-s/n
#
#     Codi_districte        Nom_districte  Codi_barri  \
# 0                1         Ciutat Vella           4
# 1                1         Ciutat Vella           4
# 2                1         Ciutat Vella           4
# 3                1         Ciutat Vella           4
# 4                5             Eixample           9
# 5                5             Eixample           9
# 6                5             Eixample           9
# 7                5             Eixample           9
# 8                5             Eixample           9
# 9                5             Eixample           9
# 10               5             Eixample           9
# 11               6               Gracia          31
# 12               6               Gracia          31
# 13               6               Gracia          31
# 14               6               Gracia          31
# 15               6               Gracia          31
# 16               6               Gracia          31
# 17               6               Gracia          31
# 18               4            Les Corts          21
# 19               4            Les Corts          21
# 20               4            Les Corts          21
# 21               4            Les Corts          21
# 22               4            Les Corts          21
# 23               4            Les Corts          21
# 24               4            Les Corts          21
# 25              10           Sant Marti          68
# 26              10           Sant Marti          68
# 27              10           Sant Marti          68
# 28              10           Sant Marti          68
# 29               3       Sants-Montjuic          18
# 30               3       Sants-Montjuic          18
# 31               3       Sants-Montjuic          18
# 32               7       Horta-Guinardo          41
# 33               7       Horta-Guinardo          41
# 34               7       Horta-Guinardo          41
# 35               7       Horta-Guinardo          41
# 36               7       Horta-Guinardo          41
# 37               7       Horta-Guinardo          41
# 38               7       Horta-Guinardo          41
# 39               5  Sarria-Sant Gervasi          22
# 40               5  Sarria-Sant Gervasi          22
# 41               5  Sarria-Sant Gervasi          22
# 42               5  Sarria-Sant Gervasi          22
# 43               5  Sarria-Sant Gervasi          22
#
#                                 Nom_barri     Clas_1   Clas_2  \
# 0   Sant Pere, Santa Caterina i la Ribera     Urbana     Fons
# 1   Sant Pere, Santa Caterina i la Ribera     Urbana     Fons
# 2   Sant Pere, Santa Caterina i la Ribera     Urbana     Fons
# 3   Sant Pere, Santa Caterina i la Ribera     Urbana     Fons
# 4          la Nova Esquerra de l'Eixample     Urbana  Trànsit
# 5          la Nova Esquerra de l'Eixample     Urbana  Trànsit
# 6          la Nova Esquerra de l'Eixample     Urbana  Trànsit
# 7          la Nova Esquerra de l'Eixample     Urbana  Trànsit
# 8          la Nova Esquerra de l'Eixample     Urbana  Trànsit
# 9          la Nova Esquerra de l'Eixample     Urbana  Trànsit
# 10         la Nova Esquerra de l'Eixample     Urbana  Trànsit
# 11                      la Vila de Gracia     Urbana  Trànsit
# 12                      la Vila de Gracia     Urbana  Trànsit
# 13                      la Vila de Gracia     Urbana  Trànsit
# 14                      la Vila de Gracia     Urbana  Trànsit
# 15                      la Vila de Gracia     Urbana  Trànsit
# 16                      la Vila de Gracia     Urbana  Trànsit
# 17                      la Vila de Gracia     Urbana  Trànsit
# 18                              Pedralbes     Urbana     Fons
# 19                              Pedralbes     Urbana     Fons
# 20                              Pedralbes     Urbana     Fons
# 21                              Pedralbes     Urbana     Fons
# 22                              Pedralbes     Urbana     Fons
# 23                              Pedralbes     Urbana     Fons
# 24                              Pedralbes     Urbana     Fons
# 25                            el Poblenou     Urbana     Fons
# 26                            el Poblenou     Urbana     Fons
# 27                            el Poblenou     Urbana     Fons
# 28                            el Poblenou     Urbana     Fons
# 29                                  Sants     Urbana     Fons
# 30                                  Sants     Urbana     Fons
# 31                                  Sants     Urbana     Fons
# 32                       la Vall d'Hebron     Urbana     Fons
# 33                       la Vall d'Hebron     Urbana     Fons
# 34                       la Vall d'Hebron     Urbana     Fons
# 35                       la Vall d'Hebron     Urbana     Fons
# 36                       la Vall d'Hebron     Urbana     Fons
# 37                       la Vall d'Hebron     Urbana     Fons
# 38                       la Vall d'Hebron     Urbana     Fons
# 39     Vallvidrera-el Tibidabo-les Planes  Suburbana     Fons
# 40     Vallvidrera-el Tibidabo-les Planes  Suburbana     Fons
# 41     Vallvidrera-el Tibidabo-les Planes  Suburbana     Fons
# 42     Vallvidrera-el Tibidabo-les Planes  Suburbana     Fons
# 43     Vallvidrera-el Tibidabo-les Planes  Suburbana     Fons
#
#     Codi_Contaminant
# 0                  8
# 1                 14
# 2                  7
# 3                 12
# 4                  8
# 5                 14
# 6                 10
# 7                  1
# 8                  6
# 9                  7
# 10                12
# 11                 8
# 12                14
# 13                10
# 14                 1
# 15                 6
# 16                 7
# 17                12
# 18                 8
# 19                14
# 20                10
# 21                 1
# 22                 6
# 23                 7
# 24                12
# 25                 8
# 26                10
# 27                 7
# 28                12
# 29                 8
# 30                 7
# 31                12
# 32                 8
# 33                14
# 34                10
# 35                 1
# 36                 6
# 37                12
# 38                 7
# 39                 8
# 40                14
# 41                10
# 42                 7
# 43                12

# %%
x.Estacio.value_counts()
# Out:
# 43    7
# 44    7
# 57    7
# 54    7
# 58    5
# 50    4
# 4     4
# 42    3
# Name: Estacio, dtype: int64

# %% [markdown]
# ### capacidad acustica

# %% [markdown]
# ###### De 55 a 75 dB
#
# ###### Es un nivel de ruido considerable. Por ejemplo, un aspirador genera 65 dB. Una calle con mucho tráfico alcanza los 75 dB. El despertador o la televisión a un volumen elevado, pueden llegar a los 75 dB, igual que una lavadora, el teléfono móvil o una batidora.
#
# ###### De 75 dB a 100 dB
#
# ###### Es un nivel alto de ruido, la sensación es molesta. Por ejemplo, en un atasco hay 90 dB de ruido. También el que suele emitir una sirena de policía.

# %% [markdown]
# TOTAL_D        Ruido total en periodo dia
# FFCC_E         Ruido de ejes ferroviarios y tranvía en período tarde
# PATIS_D        Ruido en patios interiores en período día
# OCI_N          Ruido de ocio y aglomeración de personas en período noche
# VIANANTS_E     Ruido en calles peatonales en período tarde
# VIANANTS_D     Ruido en calles peatonales en período día
# INDUST_DEN     Ruido de industria en período Lden
# INDUST_N       Ruido de industria en período noche
# INDUST_E       Ruido de industria en período tarde
# INDUST_D       Ruido de industria en período día
# FFCC_DEN       Ruido de ejes ferroviarios y tranvía en período Lden
# FFCC_N         Ruido de ejes ferroviarios y tranvía en período noche
# FFCC_D         Ruido de ejes ferroviarios y tranvía en período día
# TOTAL_E        Ruido total en periodo tarde
# GI_TR_DEN      Ruido de grandes infraestructuras viarias en período Lden
# GI_TR_N        Ruido de grandes infraestructuras viarias en período noche
# GI_TR_E        Ruido de grandes infraestructuras viarias en período tarde
# GI_TR_D        Ruido de grandes infraestructuras viarias en período día
# TRANSIT_DEN    Ruido de tráfico viario en período Lden
# TRANSIT_N      Ruido de tráfico viario en período noche
# TRANSIT_E      Ruido de tráfico viario en período tarde
# TRANSIT_D      Ruido de trafico viario en periodo dia
# TOTAL_DEN      Ruido total en período Lden
# TOTAL_N        ruido total en periodo noche
# PATIS_E        Ruido en patios interiores en período tarde

# %%
y = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\capacidad acustica\\2017_barris_soroll_bcn_long.csv")

# %%
y
# Out:
#        Codi_Districte Nom_Districte  Codi_Barri            Nom_Barri Concepte  \
# 0                   1  Ciutat Vella           1             el Raval  TOTAL_D
# 1                   1  Ciutat Vella           1             el Raval  TOTAL_D
# 2                   1  Ciutat Vella           1             el Raval  TOTAL_D
# 3                   1  Ciutat Vella           1             el Raval  TOTAL_D
# 4                   1  Ciutat Vella           1             el Raval  TOTAL_D
# ...               ...           ...         ...                  ...      ...
# 18975              10    Sant Martí          73  la Verneda i la Pau  PARCS_D
# 18976              10    Sant Martí          73  la Verneda i la Pau  PARCS_D
# 18977              10    Sant Martí          73  la Verneda i la Pau  PARCS_D
# 18978              10    Sant Martí          73  la Verneda i la Pau  PARCS_D
# 18979              10    Sant Martí          73  la Verneda i la Pau  PARCS_D
#
#       Rang_soroll   Valor
# 0          <40 dB   7.73%
# 1        40-45 dB  26.98%
# 2        45-50 dB   7.38%
# 3        50-55 dB  11.97%
# 4        55-60 dB  19.85%
# ...           ...     ...
# 18975    60-65 dB   0.00%
# 18976    65-70 dB   0.00%
# 18977    70-75 dB   0.00%
# 18978    75-80 dB   0.00%
# 18979     >=80 dB   0.00%
#
# [18980 rows x 7 columns]

# %%
y.Codi_Barri.value_counts()
# Out:
# 1     260
# 38    260
# 54    260
# 53    260
# 52    260
#      ...
# 25    260
# 24    260
# 23    260
# 22    260
# 73    260
# Name: Codi_Barri, Length: 73, dtype: int64

# %%
y = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\capacidad acustica\\2017_ciutat_mapa_estrategic_soroll_bcn_long.csv")

# %%
y
# Out:
#     Rang_soroll Concepte   Valor
# 0        <40 dB  TOTAL_D   2.60%
# 1      40-45 dB  TOTAL_D  14.49%
# 2      45-50 dB  TOTAL_D  16.38%
# 3      50-55 dB  TOTAL_D  10.53%
# 4      55-60 dB  TOTAL_D  17.06%
# ..          ...      ...     ...
# 255    60-65 dB  PARCS_D   0.00%
# 256    65-70 dB  PARCS_D   0.00%
# 257    70-75 dB  PARCS_D   0.00%
# 258    75-80 dB  PARCS_D   0.00%
# 259     >=80 dB  PARCS_D   0.00%
#
# [260 rows x 3 columns]

# %%
y = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\capacidad acustica\\2017_tramer_mapa_estrategic_soroll_bcn_long.csv")

# %%
y.TR
# Out:
#            TRAM                                           GEOM_WKT Concepte  \
# 0       T04719W  MULTILINESTRING ((430229.788593716 4586585.199...  TOTAL_D
# 1       T19941Z  MULTILINESTRING ((432928.898296899 4584019.987...  TOTAL_D
# 2       T18111R  MULTILINESTRING ((429953.263102905 4588161.440...  TOTAL_D
# 3       T03222Y  MULTILINESTRING ((427949.038250661 4580946.042...  TOTAL_D
# 4       T17625I  MULTILINESTRING ((433950.188943519 4585741.213...  TOTAL_D
# ...         ...                                                ...      ...
# 448945  T08868Y  MULTILINESTRING ((431756.999149255 4585026.456...  PATIS_E
# 448946   P98700  MULTILINESTRING ((433540.3279 4587660.4522,433...  PATIS_E
# 448947   P98690  MULTILINESTRING ((433545.366 4587658.255,43354...  PATIS_E
# 448948   P27312  MULTILINESTRING ((430555.994 4585460.656,43055...  PATIS_E
# 448949   P28659  MULTILINESTRING ((428842.519 4587255.013,42883...  PATIS_E
#
#                 Valor
# 0       70 - 75 dB(A)
# 1       45 - 50 dB(A)
# 2       55 - 60 dB(A)
# 3       60 - 65 dB(A)
# 4       55 - 60 dB(A)
# ...               ...
# 448945     < 40 dB(A)
# 448946     < 40 dB(A)
# 448947     < 40 dB(A)
# 448948     < 40 dB(A)
# 448949     < 40 dB(A)
#
# [448950 rows x 4 columns]

# %%
print(set(y.TRAM))
# Out:
# {'T18492R', 'P82041', 'T06060K', 'T21586Z', 'P25590', 'T07088A', 'T16570G', 'T17321V', 'T04380P', 'T02165C', 'P70560', 'T03292M', 'P90571', 'P82610', 'T02628M', 'T03646S', 'T00570D', 'T00526Z', 'P05050', 'T03279P', 'T02457L', 'P95912', 'T10275E', 'T05932D', 'T20978H', 'T00879V', 'T07905I', 'T17396O', 'T01162V', 'T00382B', 'T07562F', 'T12080D', 'T03197O', 'T21201V', 'T08012K', 'T01775S', 'T18944Y', 'T17661M', 'T15529B', 'T21170F', 'T00853L', 'T15178Y', 'T17246B', 'P28661', 'T10145V', 'T02047X', 'T17624H', 'P33790', 'T02418E', 'T04025Z', 'T00823F', 'T16467I', 'T04991K', 'P95980', 'T21370L', 'T01897B', 'T07272Y', 'T04596D', 'T10638L', 'T20677X', 'P29544', 'T13773D', 'P70070', 'P12860', 'P82030', 'T17868Z', 'T20750P', 'T17584Q', 'T16731F', 'T08274E', 'T21452M', 'T03362J', 'P11980', 'T02021N', 'T00496K', 'RD0127W', 'T01080U', 'T21349O', 'T12353J', 'T02392L', 'T05057L', 'T02378N', 'T08665P', 'T08690Q', 'T20323A', 'T09152Z', 'T17751N', 'T20121S', 'T06978V', 'T16373D', 'T02513C', 'T18963B', 'T09059D', 'T07964T', 'T07908L', 'T04930X', 'T10789Z', 'T13054F', 'T20416E', 'T00506V', 'T07543C', 'T01502V', 'T14335P', 'T02525G', 'T14657E', 'P25920', 'P06200', 'T04917A', 'T01501U', 'T14733Z', 'P25060', 'T10471G', 'P71440', 'P81020', 'T02397Q', 'T03296Q', 'T15943L', 'T13511J', 'T08717K', 'T04301A', 'T05841B', 'T05410I', 'T12879I', 'T00942L', 'RD0093O', 'T21007V', 'T16422V', 'P94891', 'T00677N', 'T15829K', 'T13912W', 'T17546K', 'T18337H', 'T09559S', 'T03164F', 'T08702D', 'T10510W', 'P80580', 'T17361D', 'T16334W', 'T03218C', 'T21512H', 'P60080', 'P90720', 'T18657U', 'T09366L', 'T21474S', 'RL0010J', 'T04717U', 'T21244G', 'T10606D', 'P26360', 'T12691Y', 'LRD0008', 'P27642', 'T10860P', 'T03186L', 'T09689B', 'T13854D', 'P70050', 'T01734J', 'T19456R', 'P84100', 'T17364G', 'T20888G', 'P71002', 'T09675V', 'T07975W', 'T07711A', 'T11125V', 'T12939D', 'P06423', 'T08130P', 'T04868I', 'T19335J', 'T09571O', 'T05930B', 'RD0033G', 'T02835R', 'T08921M', 'T20613H', 'T02983C', 'T20681T', 'T08594R', 'RD0027A', 'T19327J', 'T14450R', 'T10482J', 'T00141M', 'T17874X', 'T07952P', 'T13098R', 'T02388P', 'T17308Y', 'T09586V', 'T18220V', 'T03361I', 'T00247V', 'T16503V', 'T05224I', 'T06743E', 'T14839I', 'T08632G', 'LRD0020', 'T04904V', 'T00337W', 'T03312Z', 'T15951L', 'T04978N', 'T12613K', 'T03734R', 'P41200', 'T21173I', 'T07696S', 'T05289Z', 'T08096E', 'T08952T', 'T08453F', 'P80730', 'T03455N', 'T10832L', 'T05473X', 'T09938Z', 'T13526Q', 'T06090Q', 'T18733P', 'T14396C', 'T10114O', 'T12693A', 'P92010', 'T11265G', 'T07769S', 'T06251P', 'T19257M', 'P70300', 'T04956H', 'T03554P', 'P20550', 'T09441F', 'T13276R', 'T15725D', 'T18222X', 'T07026M', 'T08847T', 'P12501', 'T18251C', 'T03477T', 'T01889B', 'T07746L', 'T19666Z', 'T06572D', 'T17917R', 'T20574R', 'T02206U', 'T04181K', 'P91665', 'T10888B', 'T08476M', 'T08940P', 'T14352Q', 'P97602', 'T09329G', 'T05446U', 'T06754H', 'T11954Y', 'P60930', 'T16330S', 'T18265I', 'T20265H', 'T03926X', 'T12789H', 'P60460', 'T13701N', 'T18372K', 'P07933', 'P96380', 'T15286B', 'T07301M', 'T05182P', 'T01555I', 'T02166D', 'T04251H', 'P80880', 'LRD0017', 'T00539E', 'T15297E', 'T02119W', 'T01833L', 'P60950', 'T00019L', 'T05540R', 'P15391', 'T13978O', 'T18851U', 'T02601B', 'T00596N', 'P29410', 'T07432W', 'T08609H', 'T18776A', 'P25710', 'T21353K', 'P99381', 'P33300', 'P91043', 'P06601', 'T18235C', 'T09628O', 'T01202M', 'T09596X', 'T12141Z', 'T20060W', 'T04424K', 'T21509M', 'P21312', 'P41340', 'P08450', 'T18249I', 'T08284G', 'T04100T', 'T18494T', 'T05984P', 'T14773H', 'T02770R', 'T09855X', 'T13228J', 'T08957Y', 'T17142U', 'T12099O', 'T19466T', 'P91420', 'T20503C', 'T10779X', 'T09516H', 'T17338E', 'T10412V', 'T11359L', 'T18117X', 'T20671R', 'T02499V', 'T00364Z', 'T00818I', 'P31361', 'T18544M', 'T03112T', 'T02931Q', 'T16689U', 'P34471', 'T06157S', 'P08610', 'T07403R', 'T16926O', 'P21090', 'T01737M', 'P60430', 'P33614', 'T00149U', 'T09903O', 'T10462F', 'P82690', 'T06324P', 'T16326W', 'T02556N', 'T16964U', 'T03242C', 'T17025Q', 'P31300', 'T10094B', 'T09051V', 'T0 ...

# %%
y.GEOM_WKT.value_counts()
# Out:
# MULTILINESTRING ((430229.788593716 4586585.19905775,430181.876584091 4586593.70443592))                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# MULTILINESTRING ((428478.106811811 4585915.25031926,428490.060594814 4585884.1301785))                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# MULTILINESTRING ((430127.754912177 4587704.65461906,430060.816209381 4587757.53721234))                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# MULTILINESTRING ((429690.230175246 4584003.93314024,429626.780623465 4584075.74373195))                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# MULTILINESTRING ((428694.421330428 4583306.23365913,428666.405535848 4583338.95592216))                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# MULTILINESTRING ((429625.475121516 4586249.86512052,429562.008719935 4586209.77853945))                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# MULTILINESTRING ((430987.343656538 4580777.78137529,430897.89104365 4580715.32095714))                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# MULTILINESTRING ((431040.125955204 4581464.54102928,431044.352887507 4581454.76998228))                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# MULTILINESTRING ((434744.283509188 4585127.27857655,434748.709575741 4585135.133555,434746.592676613 4585148.81659176,434742.763739542 4585157.85763443,434740.864765082 4585161.59665447))                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# MULTILINESTRING ((428842.519 4587255.013,428838.205 4587242.538,428838.036 4587242.603,428836.796 4587243.082,428835.694 4587239.873,428824.713 4587243.689,428826.078 4587247.413,428827.487 4587251.254,428827.511 4587251.286,428827.663 4587251.526,428830.533 4587259.826,428835.386 4587258.148,428836.936 4587257.612,428842.724 4587255.606,428842.519 4587255.013),(428846.93 4587266.806,428845.039 4587261.374,428844.766 4587261.469,428843.818 4587261.8,428839.712 4587263.319,428839.146 4587261.692,428838.957 4587261.149,428838.384 4587261.361,428836.787 4587261.937,428833.555 4587263.104,428831.919 4587263.688,428834.619 4587271.214,428837.346 4587278.815,428838.969 4587278.224,428842.157 4587277.067,428843.736 4587276.494,428844.234 4587276.313,428844.015 4587275.707,428843.455 4587274.163,428847.676 4587272.636,428848.551 4587272.331,428848.82 4587272.237,428846.93 4587266.806),(428851.347 4587278.422,428851.205 4587278.016,428843.484 4587280.735,428840.275 4587281.862,428838.644 4587282.434,428841.338 4587289.94,428844.003 4587297.369,428845.651 4587296.834,428849.013 4587295.708,428850.524 4587295.201,428851.118 4587295.002,428850.963 4587294.568,428850.335 4587292.818,428854.514 4587291.311,428855.26 4587291.051,428855.692 4587290.9,428853.84 4587285.583,428851.347 4587278.422),(428858.156 4587297.298,428858.019 4587296.904,428851.937 4587299.085,428850.408 4587299.599,428847.049 4587300.727,428845.4 4587301.263,428848.107 4587308.808,428850.793 4587316.294,428852.469 4587315.733,428855.778 4587314.605,428857.338 4587314.073,428863.268 4587311.972,428863.087 4587311.452,428860.644 4587304.439,428858.156 4587297.298),(428867.419 4587323.307,428865.551 4587317.947,428865.185 4587318.076,428859.99 4587319.914,428859.369 4587318.155,428859.201 4587317.679,428858.815 4587317.816,428857.124 4587318.406,428853.854 4587319.548,428852.173 4587320.13,428854.889 4587327.675,428857.604 4587335.217,428859.326 4587334.617,428862.547 4587333.494,428864.664 4587332.758,428864.459 4587332.167,428863.902 4587330.566,428868.105 4587329.105,428869.295 4587328.691,428867.419 4587323.307),(428871.35 4587335.182,428871.196 4587334.748,428865.508 4587336.669,428863.81 4587337.242,428860.64 4587338.311,428858.926 4587338.89,428862.949 4587350.065,428864.408 4587349.093,428871.886 4587344.116,428874.02 4587342.695,428873.624 4587341.581,428871.925 4587336.8,428871.35 4587335.182),(428966.381 4587287.478,428959.654 4587268.746,428959.465 4587268.219,428959.653 4587268.151,428958.084 4587263.783,428957.892 4587263.84,428952.854 4587249.811,428946.076 4587230.936,428939.311 4587212.0967,428938.43 4587209.644,428937.608 4587209.939,428931.393 4587212.1729,428917.787 4587217.063,428913.832 4587218.477,428912.663 4587220.526,428909.468 4587221.668,428907.266 4587220.824,428903.311 4587222.237,428902.194 4587217.134,428901.706 4587217.374,428901.52 4587217.465,428900.899 4587215.73,428901.541 4587215.415,428900.096 4587212.474,428899.501 4587211.263,428896.048 4587212.513,428880.989 4587217.963,428881.963 4587222.71,428882.705 4587222.469,428883.244 4587224.126,428882.574 4587224.304,428885.051 4587228.944,428881.094 4587230.35,428879.928 4587232.404,428876.604 4587233.586,428874.405 4587232.745,428870.442 4587234.136,428850.515 4587241.132,428849.973 4587241.323,428857.706 4587262.948,428857.95 4587263.631,428863.281 4587278.54,428864.475 4587281.878,428871.224 4587300.752,428877.974 4587319.628,428884.089 4587336.729,428884.816 4587336.279,428889.245 4587333.538,428889.427 4587333.423,428890.406 4587332.808,428891.568 4587332.107,428892.742 4587331.428,428893.929 4587330.772,428895.128 4587330.138,428896.339 4587329.526,428897.577 4587328.928,428899.026 4587328.206,428900.47 4587327.499,428901.918 4587326.803,428903.37 4587326.116,428904.825 4587325.439,428907.817 4587324.076,428909.222 4587323.435,428915.217 4587320.703,428916.415 4587320.192,428917.681 4587319.676,428918.957 4587319.182,428920.241 4587318.708,428921.559 4587318.247,428923.781 4587317.38 ...
# Name: GEOM_WKT, Length: 17958, dtype: int64

# %%
y = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\capacidad acustica\ATMOSFERA_MES_SUPRAMUN_2018.csv")

# %%
y.SHAPE.value_counts().sum()
# Out:
# 45853

# %%
y
# Out:
#                                       FID  \
# 0      ATMOSFERA_MES_SUPRAMUN_2018.134902
# 1      ATMOSFERA_MES_SUPRAMUN_2018.109272
# 2      ATMOSFERA_MES_SUPRAMUN_2018.102492
# 3      ATMOSFERA_MES_SUPRAMUN_2018.137490
# 4       ATMOSFERA_MES_SUPRAMUN_2018.95114
# ...                                   ...
# 45848  ATMOSFERA_MES_SUPRAMUN_2018.124248
# 45849   ATMOSFERA_MES_SUPRAMUN_2018.99475
# 45850  ATMOSFERA_MES_SUPRAMUN_2018.109617
# 45851  ATMOSFERA_MES_SUPRAMUN_2018.117236
# 45852  ATMOSFERA_MES_SUPRAMUN_2018.129286
#
#                                                    SHAPE  IDTRAM_AGL   IDTRAM  \
# 0      MULTILINESTRING ((418934.6899 4602170.0496, 41...        1717    27124
# 1      MULTILINESTRING ((428084.3613 4582246.8167, 42...       17112  T18520E
# 2      MULTILINESTRING ((432690.9162 4586956.886, 432...       10332  T06162P
# 3      MULTILINESTRING ((417967.7731 4603161.4321, 41...        4305    29712
# 4      MULTILINESTRING ((430415.0153 4581110.6482, 43...        2954  T01133Q
# ...                                                  ...         ...      ...
# 45848  MULTILINESTRING ((354437.3837 4553283.6379, 35...        1086     1182
# 45849  MULTILINESTRING ((427626.996 4583797.712, 4276...        7315   P33000
# 45850  MULTILINESTRING ((432364.9082 4582679.8029, 43...       17457  T10145V
# 45851  MULTILINESTRING ((422556.9647 4579922.0494, 42...        2858     3905
# 45852  MULTILINESTRING ((423739.0246 4602251.3792, 42...        1915     1918
#
#       IDAGLO CODI_INE  TVLDIA  TVLVES  TVLNIT  TVLDEN  ...  TOTVES  TOTNIT  \
# 0       VOC2    08279      58      58      49      59  ...      58      49
# 1       BCN1    08019      62      59      54      63  ...      59      54
# 2       BCN1    08019      68      66      61      70  ...      66      61
# 3       VOC2    08279      59      59      50      60  ...      59      50
# 4       BCN1    08019      56      54      49      58  ...      54      49
# ...      ...      ...     ...     ...     ...     ...  ...     ...     ...
# 45848    TAR    43148      58      58      55      62  ...      58      55
# 45849   BCN1    08019      42      40      35      44  ...      40      35
# 45850   BCN1    08019      67      65      60      68  ...      65      60
# 45851   BLLI    08217      57      57      51      59  ...      57      51
# 45852   VOCI    08187      59      59      50      60  ...      59      50
#
#        TOTDEN  VLDIA  VLVES  VLNIT  SVLDIA  SVLVES  SVLNIT  OBJECTID
# 0          59     65     65     55       0       0       0    134902
# 1          63      0      0      0       0       0       0    109272
# 2          70      0      0      0       0       0       0    102492
# 3          60     65     65     55       0       0       0    137490
# 4          58      0      0      0       0       0       0     95114
# ...       ...    ...    ...    ...     ...     ...     ...       ...
# 45848      62     65     65     55       0       0       0    124248
# 45849      44      0      0      0       0       0       0     99475
# 45850      68      0      0      0       0       0       0    109617
# 45851      59     65     65     55       0       0       0    117236
# 45852      60     65     65     55       0       0       0    129286
#
# [45853 rows x 53 columns]

# %% [markdown]
# ### Green points

# %% [markdown]
# delete non necesary.

# %%
y = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\\arbolado\puntos_ecologicos.csv")

# %%
y = y.drop(columns=["register_id", "institution_id", "institution_name", "addresses_roadtype_id", "addresses_roadtype_name", "values_description", "secondary_filters_fullpath", "secondary_filters_tree", 
                "secondary_filters_asia_id", "geo_epgs_25831_x", "geo_epgs_25831_y", "addresses_road_id", "addresses_end_street_number", "addresses_neighborhood_id", "addresses_neighborhood_id",
                "values_id", "values_attribute_id", "values_category", "values_attribute_name", "values_value", "values_outstanding", "secondary_filters_id", 
                "addresses_town", "addresses_main_address", "addresses_type"])

# %%
y["secondary_filters_name"].value_counts()
# Out:
# Punts verds mòbils            97
# Punts verds de barri          27
# Horts urbans                  15
# Punts verds de zona            7
# Punts verds col·laboradors     1
# Name: secondary_filters_name, dtype: int64

# %%
y = y.drop(y[y["secondary_filters_name"] == "Punts de recollida d'arbres de Nadal"].index)

# %%
y = y.drop(y[y["secondary_filters_name"] == "Contenidors de sal"].index)

# %%
y = y.drop(y[y["secondary_filters_name"] == "Punts de roba amiga"].index)

# %%
y = y.drop(y[y["secondary_filters_name"] == "Punts de recollida d'arbres de Nadal"].index)

# %%
n = y["secondary_filters_name"] == "Punts verds col·laboradors"
y[n]
# Out:
#       register_id                                               name  \
# 437  ﻿75990029216  Punt Verd de Barri Col·laborador - Recuperació...
#
#      institution_id institution_name                    created  \
# 437             NaN              NaN  1996-09-17T00:00:00+02:00
#
#                              modified  addresses_roadtype_id  \
# 437  2023-02-28T13:41:18.437140+01:00                    NaN
#
#      addresses_roadtype_name  addresses_road_id       addresses_road_name  \
# 437                      NaN             152202  Carrer de les Guilleries
#
#      ...  values_description  secondary_filters_id  \
# 437  ...                 NaN              65731068
#
#          secondary_filters_name  \
# 437  Punts verds col·laboradors
#
#                             secondary_filters_fullpath  \
# 437  Planol BCN >> Medi ambient >> Medi ambient >> ...
#
#      secondary_filters_tree secondary_filters_asia_id  geo_epgs_25831_x  \
# 437                     651            65103012000000     429487.034971
#
#     geo_epgs_25831_y  geo_epgs_4326_x  geo_epgs_4326_y
# 437     4.583912e+06         41.40366          2.15641
#
# [1 rows x 36 columns]

# %% [markdown]
# ### Huertos urbanos

# %%
huerto = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\\arbolado\huertos.csv")
huerto
# Out:
#      register_id                            name  institution_id  \
# 0   ﻿99400400469        Hort Urbà de Can Peguera             NaN
# 1   ﻿98180122541     Hort Urbà Masia Can Mestres             NaN
# 2    ﻿1156115521       Hort Urbà Masia Can Soler             NaN
# 3   ﻿99400186934                       Hort Urbà    9.940041e+10
# 4   ﻿99400100015   Hort Urbà Parc de la Trinitat             NaN
# 5   ﻿99400183714  Hort Urbà de Sant Pau del Camp             NaN
# 6   ﻿99400400467         Hort Urbà Baró de Viver             NaN
# 7   ﻿99400100007              Hort Urbà de l'Avi             NaN
# 8   ﻿99400100012             Hort Urbà de Turull             NaN
# 9   ﻿99400100016      Hort Urbà Masia Can Cadena             NaN
# 10  ﻿99400170336          Hort Urbà Torre Melina             NaN
# 11  ﻿99400200051          Hort Urbà de Pedralbes             NaN
# 12  ﻿99400363859           Hort Urbà Can Pujades             NaN
# 13  ﻿99400180128       Hort Urbà Sagrada Família             NaN
# 14  ﻿99400186258            Hort Urbà Collserola             NaN
#
#       institution_name                    created  \
# 0                  NaN  2015-11-04T12:11:42+01:00
# 1                  NaN  1998-06-29T00:00:00+02:00
# 2                  NaN  2001-06-05T00:00:00+02:00
# 3   La Casa de l'Aigua  2007-07-06T08:51:21+02:00
# 4                  NaN  2004-11-23T14:00:35+01:00
# 5                  NaN  2007-05-21T13:46:45+02:00
# 6                  NaN  2015-11-04T11:24:12+01:00
# 7                  NaN  2004-11-23T12:43:51+01:00
# 8                  NaN  2004-11-23T13:25:29+01:00
# 9                  NaN  2004-11-23T14:24:00+01:00
# 10                 NaN  2006-10-20T14:18:50+02:00
# 11                 NaN  2008-02-12T09:44:25+01:00
# 12                 NaN  2014-11-20T12:01:02+01:00
# 13                 NaN  2007-03-30T08:54:17+02:00
# 14                 NaN  2007-06-26T08:38:52+02:00
#
#                             modified  addresses_roadtype_id  \
# 0   2022-09-23T12:49:54.202656+02:00                    NaN
# 1   2022-09-23T12:41:11.292400+02:00                    NaN
# 2   2022-09-23T12:49:01.767216+02:00                    NaN
# 3   2022-09-23T12:51:00.902439+02:00                    NaN
# 4   2022-09-23T12:52:43.616445+02:00                    NaN
# 5   2022-09-23T12:27:35.260523+02:00                    NaN
# 6   2022-09-23T12:51:57.064996+02:00                    NaN
# 7   2022-09-23T12:47:45.631318+02:00                    NaN
# 8   2022-09-23T12:46:40.315876+02:00                    NaN
# 9   2022-09-23T12:53:39.525173+02:00                    NaN
# 10  2022-09-23T12:43:04.088082+02:00                    NaN
# 11  2022-09-23T12:42:00.469725+02:00                    NaN
# 12  2022-09-23T12:44:02.506871+02:00                    NaN
# 13  2022-09-23T12:29:23.036079+02:00                    NaN
# 14  2022-09-23T12:45:40.467359+02:00                    NaN
#
#     addresses_roadtype_name  addresses_road_id  addresses_road_name  ...  \
# 0                       NaN              57100              C Camós  ...
# 1                       NaN              58634        Camí Can Clos  ...
# 2                       NaN             148409      Ctra Sant Cugat  ...
# 3                       NaN             139907              C Garbí  ...
# 4                       NaN             314100      Pg Santa Coloma  ...
# 5                       NaN                500        C Abat Safont  ...
# 6                       NaN             314100      Pg Santa Coloma  ...
# 7                       NaN             340905  C Torrent del Remei  ...
# 8                       NaN             348350          Ptge Turull  ...
# 9                       NaN             208205            C Menorca  ...
# 10                      NaN             339815    Camí Torre Melina  ...
# 11                      NaN              72704          C Castellet  ...
# 12                      NaN             700168         Camí Múrgola  ...
# 13                      NaN             238400            C Padilla  ...
# 14                      NaN              66803   C Carles Pirozzini  ...
#
#     values_description  secondary_filters_id  secondary_filters_name  \
# 0                  NaN              65731076            Horts urbans
# 1                  NaN              65731076            Horts urbans
# 2                  NaN              65731076            Horts urbans
# 3                  NaN              65731076            Horts urbans
# 4                  NaN              65731076            Horts urbans
# 5                  NaN              65731076            Horts urbans
# 6                  NaN              65731076            Horts urbans
# 7                  NaN              65731076            Horts urbans
# 8                  NaN              65731076            Horts urbans
# 9                  NaN              65731076            Horts urbans
# 10          Informació              65731076            Horts urbans
# 11                 NaN              65731076            Horts urbans
# 12                 NaN              65731076            Horts urbans
# 13                 NaN              65731076            Horts urbans
# 14          Informació              65731076            Horts urbans
#
#                            secondary_filters_fullpath  secondary_filters_tree  \
# 0   Planol BCN >> Medi ambient >> Medi ambient >> ...                     651
# 1   Planol BCN >> Medi ambient >> Medi ambient >> ...                     651
# 2   Planol BCN >> Medi ambient >> Medi ambient >> ...                     651
# 3   Planol BCN >> Medi ambient >> Medi ambient >> ...                     651
# 4   Planol BCN >> Medi ambient >> Medi ambient >> ...                     651
# 5   Planol BCN >> Medi ambient >> Medi ambient >> ...                     651
# 6   Planol BCN >> Medi ambient >> Medi ambient >> ...                     651
# 7   Planol BCN >> Medi ambient >> Medi ambient >> ...                     651
# 8   Planol BCN >> Medi ambient >> Medi ambient >> ...                     651
# 9   Planol BCN >> Medi ambient >> Medi ambient >> ...                     651
# 10  Planol BCN >> Medi ambient >> Medi ambient >> ...                     651
# 11  Planol BCN >> Medi ambient >> Medi ambient >> ...                     651
# 12  Planol BCN >> Medi ambient >> Medi ambient >> ...                     651
# 13  Planol BCN >> Medi ambient >> Medi ambient >> ...                     651
# 14  Planol BCN >> Medi ambient >> Medi ambient >> ...                     651
#
#    secondary_filters_asia_id  geo_epgs_25831_x geo_epgs_25831_y  \
# 0             65103012000008     430170.170636     4.587276e+06
# 1             65103012000008     428498.372611     4.579043e+06
# 2             65103012000008     427362.046099     4.586306e+06
# 3             65103012000008     432182.013692     4.589361e+06
# 4             65103012000008     432814.485640     4.588944e+06
# 5             65103012000008     430530.332476     4.580808e+06
# 6             65103012000008     433080.424051     4.588992e+06
# 7             65103012000008     428816.369204     4.585246e+06
# 8             65103012000008     428777.193634     4.585011e+06
# 9             65103012000008     432996.621503     4.585782e+06
# 10            65103012000008     425696.028441     4.581010e+06
# 11            65103012000008     425728.947701     4.582914e+06
# 12            65103012000008     424660.180575     4.585200e+06
# 13            65103012000008     431511.282331     4.583783e+06
# 14            65103012000008     427665.696358     4.585340e+06
#
#     geo_epgs_4326_x  geo_epgs_4326_y
# 0         41.434021         2.164193
# 1         41.359715         2.145157
# 2         41.425029         2.130702
# 3         41.452965         2.188037
# 4         41.449269         2.195655
# 5         41.375794         2.169246
# 6         41.449723         2.198833
# 7         41.415613         2.148230
# 8         41.413495         2.147789
# 9         41.420806         2.198186
# 10        41.377183         2.111416
# 11        41.394332         2.111577
# 12        41.414821         2.098509
# 13        41.402677         2.180639
# 14        41.416357         2.134451
#
# [15 rows x 36 columns]

# %%
huerto = huerto.drop(columns=["register_id", "institution_id", "institution_name", "addresses_roadtype_id", "addresses_roadtype_name", "values_description", "secondary_filters_fullpath", "secondary_filters_tree", 
                "secondary_filters_asia_id", "geo_epgs_25831_x", "geo_epgs_25831_y", "addresses_road_id", "addresses_end_street_number", "addresses_neighborhood_id", "addresses_neighborhood_id",
                "values_id", "values_attribute_id", "values_category", "values_attribute_name", "values_value", "values_outstanding", "secondary_filters_id", 
                "addresses_town", "addresses_main_address", "addresses_type"])

# %% [markdown]
# ### Jardin interiors.

# %%
interior = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\\arbolado\jardin_interiors.csv")

# %%
interior = interior.drop(columns=["register_id", "institution_id", "institution_name", "addresses_roadtype_id", "addresses_roadtype_name", "values_description", 
                "geo_epgs_25831_x", "geo_epgs_25831_y", "addresses_road_id", "addresses_end_street_number", "addresses_neighborhood_id", "addresses_neighborhood_id",
                "values_id", "values_attribute_id", "values_category", "values_attribute_name", "values_value", "values_outstanding", 
                "addresses_town", "addresses_main_address", "addresses_type"])

# %% [markdown]
# Change names of columns

# %%
interior.shape
# Out:
# (49, 11)

# %% [markdown]
# ### puntos ecologicos.

# %% [markdown]
# mateix del aoltra data frame

# %%
punts = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\\arbolado\puntos_ecologicos.csv")

# %% [markdown]
# ### refugis.

# %%
refugi = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\\arbolado\\refugi.csv")

# %% [markdown]
# refiguios tipo escuelas, parques, lugares tipo asilos bibliotecas, de espacios publicos.

# %%
refugi
# Out:
#       register_id                                     name  institution_id  \
# 0    ﻿92086005760                     Biblioteca Canyelles             NaN
# 1    ﻿92168165957                       Escola Ramon Casas             NaN
# 2    ﻿92086011165          Casal de Gent Gran Parc Sandaru             NaN
# 3    ﻿99085102712                     Parc de Diagonal Mar             NaN
# 4    ﻿92168175469         Centre Esportiu Municipal Perill             NaN
# ..            ...                                      ...             ...
# 196  ﻿92171135342    Centre Esportiu Municipal Nova Icària             NaN
# 197  ﻿99400342694  Biblioteca Sant Gervasi - Joan Maragall             NaN
# 198  ﻿99400694393            Casal de Gent Gran Can Novell             NaN
# 199  ﻿95025093613               Casal de Gent Gran La Capa             NaN
# 200  ﻿99400637478            Casal de Barri Transformadors             NaN
#
#     institution_name                           created  \
# 0                NaN         1986-05-21T00:00:00+02:00
# 1                NaN         1989-12-04T00:00:00+01:00
# 2                NaN         1985-05-21T00:00:00+02:00
# 3                NaN         1999-03-26T00:00:00+01:00
# 4                NaN         1989-10-26T00:00:00+01:00
# ..               ...                               ...
# 196              NaN         1992-06-19T00:00:00+02:00
# 197              NaN         2014-05-15T15:03:15+02:00
# 198              NaN  2022-06-28T12:08:56.451907+02:00
# 199              NaN         1995-01-25T00:00:00+01:00
# 200              NaN         2019-09-23T14:07:17+02:00
#
#                              modified  addresses_roadtype_id  \
# 0    2023-02-16T09:52:36.412303+01:00                    NaN
# 1    2023-02-16T09:52:27.242319+01:00                    NaN
# 2    2023-02-16T09:52:33.285232+01:00                    NaN
# 3    2023-02-16T09:52:23.104422+01:00                    NaN
# 4    2023-02-16T09:52:26.550092+01:00                    NaN
# ..                                ...                    ...
# 196  2023-02-16T09:52:26.299338+01:00                    NaN
# 197  2023-02-16T09:52:18.358981+01:00                    NaN
# 198  2023-02-16T09:52:33.671067+01:00                    NaN
# 199  2023-02-16T09:52:25.111934+01:00                    NaN
# 200  2023-02-16T09:52:34.014638+01:00                    NaN
#
#      addresses_roadtype_name  addresses_road_id  \
# 0                        NaN             153158
# 1                        NaN             700714
# 2                        NaN              50803
# 3                        NaN             186703
# 4                        NaN             251102
# ..                       ...                ...
# 196                      NaN              62609
# 197                      NaN             302203
# 198                      NaN              52605
# 199                      NaN              12600
# 200                      NaN              28305
#
#                     addresses_road_name  ...  values_attribute_id  \
# 0           Ronda de la Guineueta Vella  ...             100002.0
# 1                      Carrer del Platí  ...             100002.0
# 2                  C Buenaventura Muñoz  ...             100002.0
# 3                       Carrer de Llull  ...             100003.0
# 4                              C Perill  ...             100002.0
# ..                                  ...  ...                  ...
# 196                           Av Icària  ...             100002.0
# 197  Carrer de Sant Gervasi de Cassoles  ...             100002.0
# 198                 Carrer de Caballero  ...             100002.0
# 199              Carrer dels Alts Forns  ...             100002.0
# 200                       C Ausiàs Marc  ...             100002.0
#
#           values_category  values_attribute_name  \
# 0    Informació d'interès                 E-mail
# 1    Informació d'interès                 E-mail
# 2    Informació d'interès                 E-mail
# 3    Informació d'interès                    Web
# 4    Informació d'interès                 E-mail
# ..                    ...                    ...
# 196  Informació d'interès                 E-mail
# 197  Informació d'interès                 E-mail
# 198  Informació d'interès                 E-mail
# 199  Informació d'interès                 E-mail
# 200  Informació d'interès                 E-mail
#
#                       values_value  values_outstanding values_description  \
# 0           b.barcelona.c@diba.cat                True                NaN
# 1                a8002976@xtec.cat                True                NaN
# 2      casalgg.parcsandaru@bcn.cat                True                NaN
# 3       https://link.bcn.cat/cPdDM                True                NaN
# 4           perill@eurofitness.com                True                NaN
# ..                             ...                 ...                ...
# 196        recepcio@novaicaria.com                True                NaN
# 197       b.barcelona.jmg@diba.cat                True                NaN
# 198       gentgranlescorts@bcn.cat                True                NaN
# 199           lamarina@esport3.org                True                NaN
# 200  casaltransformadors@gmail.com                True                NaN
#
#      geo_epgs_25831_x geo_epgs_25831_y  geo_epgs_4326_x  geo_epgs_4326_y
# 0       430192.917191     4.588362e+06        41.443804         2.164340
# 1       427595.967414     4.578935e+06        41.358670         2.134383
# 2       431844.899337     4.582567e+06        41.391746         2.184767
# 3       434157.960807     4.584404e+06        41.408490         2.212232
# 4       429909.760963     4.583438e+06        41.399432         2.161521
# ..                ...              ...              ...              ...
# 196     432953.634548     4.582628e+06        41.392394         2.198021
# 197     427783.024467     4.584184e+06        41.405955         2.135993
# 198     427582.425000     4.581553e+06        41.382243         2.133908
# 199     428295.253581     4.579072e+06        41.359964         2.142726
# 200     431331.536286     4.582762e+06        41.393462         2.178605
#
# [201 rows x 31 columns]

# %%
# eliminar variables y telefons
refugi["values_category"].value_counts()
# Out:
# Informació d'interès    193
# Variables                 2
# Telèfons                  2
# Name: values_category, dtype: int64

# %%
refugi.columns
# Out:
# Index(['register_id', 'name', 'institution_id', 'institution_name', 'created',
#        'modified', 'addresses_roadtype_id', 'addresses_roadtype_name',
#        'addresses_road_id', 'addresses_road_name',
#        'addresses_start_street_number', 'addresses_end_street_number',
#        'addresses_neighborhood_id', 'addresses_neighborhood_name',
#        'addresses_district_id', 'addresses_district_name',
#        'addresses_zip_code', 'addresses_town', 'addresses_main_address',
#        'addresses_type', 'values_id', 'values_attribute_id', 'values_category',
#        'values_attribute_name', 'values_value', 'values_outstanding',
#        'values_description', 'geo_epgs_25831_x', 'geo_epgs_25831_y',
#        'geo_epgs_4326_x', 'geo_epgs_4326_y'],
#       dtype='object')

# %% [markdown]
# ### Arbolado.

# %%
viari = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\\arbolado\\arbrat\OD_Arbrat_Viari_BCN.csv")

# %%
viari.columns
# Out:
# Index(['codi', 'x_etrs89', 'y_etrs89', 'latitud', 'longitud', 'tipus_element',
#        'espai_verd', 'adreca', 'cat_especie_id', 'nom_cientific',
#        'nom_castella', 'nom_catala', 'categoria_arbrat', 'data_plantacio',
#        'tipus_aigua', 'tipus_reg', 'geom', 'catalogacio', 'codi_barri',
#        'nom_barri', 'codi_districte', 'nom_districte'],
#       dtype='object')

# %%
viari = viari.drop(columns=["codi", "x_etrs89", "y_etrs89", "tipus_element", "cat_especie_id", "tipus_aigua", "tipus_reg", "nom_catala", "geom", "catalogacio"])

# %%
viari
# Out:
#           latitud  longitud                                       espai_verd  \
# 0       41.437287  2.165353                      Central de Nou Barris, Parc
# 1       41.437335  2.165436                      Central de Nou Barris, Parc
# 2       41.437769  2.162530                      Central de Nou Barris, Parc
# 3       41.437788  2.162501                      Central de Nou Barris, Parc
# 4       41.437810  2.162471                      Central de Nou Barris, Parc
# ...           ...       ...                                              ...
# 153827  41.419993  2.190518                                              NaN
# 153828  41.420038  2.190579                                              NaN
# 153829  41.419800  2.191147                                              NaN
# 153830  41.419979  2.191137                                              NaN
# 153831  41.419716  2.191138  Hondures, c. - Sagrera, c. - Josep Estivill, c.
#
#                            adreca                    nom_cientific  \
# 0            Pg Fabra i Puig, 450  Fraxinus angustifolia 'Raywood'
# 1            Pg Fabra i Puig, 450  Fraxinus angustifolia 'Raywood'
# 2         C\ Doctor Letamendi, 90             Platanus x hispanica
# 3         C\ Doctor Letamendi, 90             Platanus x hispanica
# 4         C\ Doctor Letamendi, 90             Platanus x hispanica
# ...                           ...                              ...
# 153827      C\ Josep Estivill, 65                  Melia azedarach
# 153828           Ptge Bofarull, 2                  Melia azedarach
# 153829  C\ Gran de la Sagrera, 12                  Melia azedarach
# 153830  C\ Gran de la Sagrera, 12                  Melia azedarach
# 153831  C\ Gran de la Sagrera, 49                 Celtis australis
#
#            nom_castella categoria_arbrat data_plantacio  codi_barri  \
# 0                     -          PRIMERA     2022-02-15        48.0
# 1                     -          PRIMERA     2022-02-15        48.0
# 2               Plátano           SEGONA            NaN        43.0
# 3               Plátano           SEGONA            NaN        43.0
# 4               Plátano           SEGONA            NaN        43.0
# ...                 ...              ...            ...         ...
# 153827  Melia; cinamomo          PRIMERA     2023-02-04        61.0
# 153828  Melia; cinamomo          PRIMERA     2023-02-04        61.0
# 153829  Melia; cinamomo          PRIMERA     2023-02-04        61.0
# 153830  Melia; cinamomo          PRIMERA     2023-02-04        61.0
# 153831            Almez           SEGONA            NaN        61.0
#
#            nom_barri  codi_districte     nom_districte
# 0       LA GUINEUETA               8        NOU BARRIS
# 1       LA GUINEUETA               8        NOU BARRIS
# 2              HORTA               7  HORTA - GUINARDÓ
# 3              HORTA               7  HORTA - GUINARDÓ
# 4              HORTA               7  HORTA - GUINARDÓ
# ...              ...             ...               ...
# 153827    LA SAGRERA               9       SANT ANDREU
# 153828    LA SAGRERA               9       SANT ANDREU
# 153829    LA SAGRERA               9       SANT ANDREU
# 153830    LA SAGRERA               9       SANT ANDREU
# 153831    LA SAGRERA               9       SANT ANDREU
#
# [153832 rows x 12 columns]

# %%
viari.shape
# Out:
# (153832, 12)

# %% [markdown]
# ### arbrat parcs

# %% [markdown]
# located in the squares, flower beds, gazebos or small garden spaces

# %%
parcs = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\\arbolado\\arbrat\OD_Arbrat_Parcs_BCN.csv")

# %%
parcs = parcs.drop(columns=["codi", "x_etrs89", "y_etrs89", "tipus_element", "cat_especie_id", "tipus_aigua", "tipus_reg", "nom_catala", "geom", "catalogacio"])

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[230], line 1
# ----> 1 parcs = parcs.drop(columns=["codi", "x_etrs89", "y_etrs89", "tipus_element", "cat_especie_id", "tipus_aigua", "tipus_reg", "nom_catala", "geom", "catalogacio"])
#
# File c:\Users\ima_n\miniconda2\envs\final_proy\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\ima_n\miniconda2\envs\final_proy\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File c:\Users\ima_n\miniconda2\envs\final_proy\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\ima_n\miniconda2\envs\final_proy\lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File c:\Users\ima_n\miniconda2\envs\final_proy\lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File c:\Users\ima_n\miniconda2\envs\final_proy\lib\site-packages\pandas\core\indexes\base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['codi', 'x_etrs89', 'y_etrs89', 'tipus_element', 'cat_especie_id', 'tipus_aigua', 'tipus_reg', 'nom_catala', 'geom', 'catalogacio'] not found in axis"

# %%
parcs.shape
# Out:
# (35922, 12)

# %% [markdown]
# ### Arbrat Zona

# %%
zona = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\\arbolado\\arbrat\OD_Arbrat_Zona_BCN.csv")

# %%
zona = zona.drop(columns=["codi", "x_etrs89", "y_etrs89", "tipus_element", "cat_especie_id", "tipus_aigua", "tipus_reg", "nom_catala", "geom", "catalogacio"])

# %%
zona.data_plantacio.isna().sum()
# Out:
# 40345

# %%
zona.shape
# Out:
# (43392, 22)
