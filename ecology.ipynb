# %% [markdown]
# # Environment
# ## Ayuntamiento de Barcelona

# %% [markdown]
# ### Arbolado.

# %%
import pandas as pd

# %%
x = pd.read_csv("D:\ironhack\proyectos\Barcelona_UrbanAnalysis\csv\calidad de aire\per_mes\\2022_03_Marc_qualitat_aire_BCN.csv")

# %%
# Out:
#       CODI_PROVINCIA  PROVINCIA  CODI_MUNICIPI   MUNICIPI  ESTACIO  \
# 0                  8  Barcelona             19  Barcelona        4
# 1                  8  Barcelona             19  Barcelona        4
# 2                  8  Barcelona             19  Barcelona        4
# 3                  8  Barcelona             19  Barcelona        4
# 4                  8  Barcelona             19  Barcelona        4
# ...              ...        ...            ...        ...      ...
# 1982               8  Barcelona             19  Barcelona       58
# 1983               8  Barcelona             19  Barcelona       58
# 1984               8  Barcelona             19  Barcelona       58
# 1985               8  Barcelona             19  Barcelona       58
# 1986               8  Barcelona             19  Barcelona       58
#
#       CODI_CONTAMINANT   ANY  MES  DIA    H01  ...    H20  V20   H21  V21  \
# 0                    7  2022    3    1    1.0  ...    1.0    V   2.0    V
# ...

# %% [markdown]
# Arbolado de la ciudad de barcelona

# %%
x = pd.read_csv("C:\Users\ima_n\Downloads\\2017_poblacio_exposada_ciutat_mapa_estrategic_soroll_bcn_long.csv")
# Out:
#   Cell In[6], line 1
#     x = pd.read_csv("C:\Users\ima_n\Downloads\\2017_poblacio_exposada_ciutat_mapa_estrategic_soroll_bcn_long.csv")
#                                                                                                                  ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
